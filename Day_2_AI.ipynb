# %% [markdown]
# <a href="https://colab.research.google.com/github/Sapnajolly/Artificial-Intelligence/blob/main/Day_2_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Welcome to Day 2 of AI Challenge")
# Out:
# Hello, Welcome to Day 2 of AI Challenge

# %%
from collections import Counter

sentence = "the cat sat on the mat and the cat slept"

words = sentence.split()
freq = Counter(words)

for word, count in freq.most_common():
    print(f"{word}: {count}")
# Out:
# the: 3
# cat: 2
# sat: 1
# on: 1
# mat: 1
# and: 1
# slept: 1

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)   # strip punctuation
    text = re.sub(r'\s+', ' ', text)       # normalize whitespace
    text = text.strip()
    return text

raw = "  Hello, All!!!   I am working on Day 2 for the AI Challenge  "
print(clean_text(raw))
# Out:
# hello all i am working on day 2 for the ai challenge
